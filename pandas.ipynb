# %%
data=[]
import random
names=["anil","ashok","rajesh","pavan","jay","akhil"]
age=range(23,60)
sal=[123456,23456,54321,2345678,8765432,56789,765432134,3456,3456,34567,34567]
for i in xrange(1000):
    data.append({"id":i,"name":random.choice(names),"sal":random.choice(sal),"age":random.choice(age)})
print data[:10]
# Out:
# [{'age': 58, 'sal': 8765432, 'id': 0, 'name': 'rajesh'}, {'age': 32, 'sal': 8765432, 'id': 1, 'name': 'ashok'}, {'age': 52, 'sal': 3456, 'id': 2, 'name': 'pavan'}, {'age': 30, 'sal': 3456, 'id': 3, 'name': 'jay'}, {'age': 43, 'sal': 54321, 'id': 4, 'name': 'pavan'}, {'age': 31, 'sal': 3456, 'id': 5, 'name': 'ashok'}, {'age': 48, 'sal': 54321, 'id': 6, 'name': 'rajesh'}, {'age': 55, 'sal': 2345678, 'id': 7, 'name': 'jay'}, {'age': 27, 'sal': 56789, 'id': 8, 'name': 'anil'}, {'age': 41, 'sal': 2345678, 'id': 9, 'name': 'pavan'}]

# %%
print type(data)
# Out:
# <type 'list'>

# %%
import pandas as pd

# %%
df=pd.DataFrame(data)
print df
# Out:
#      age   id    name        sal
# 0     58    0  rajesh    8765432
# 1     32    1   ashok    8765432
# 2     52    2   pavan       3456
# 3     30    3     jay       3456
# 4     43    4   pavan      54321
# 5     31    5   ashok       3456
# 6     48    6  rajesh      54321
# 7     55    7     jay    2345678
# 8     27    8    anil      56789
# 9     41    9   pavan    2345678
# 10    32   10   akhil    2345678
# 11    51   11     jay      34567
# 12    38   12   akhil       3456
# 13    30   13   pavan      56789
# 14    37   14     jay       3456
# 15    48   15   pavan      54321
# 16    34   16   pavan       3456
# 17    56   17     jay      23456
# 18    50   18    anil       3456
# 19    57   19   ashok      23456
# 20    37   20    anil  765432134
# 21    43   21     jay  765432134
# 22    30   22  rajesh  765432134
# 23    37   23  rajesh      34567
# 24    57   24     jay      34567
# 25    42   25    anil      56789
# 26    54   26    anil      34567
# ...

# %%
df[df.age==25]
# Out:
#      age   id    name        sal
# 45    25   45   ashok      23456
# 65    25   65   pavan       3456
# 117   25  117    anil      34567
# 174   25  174     jay     123456
# 220   25  220   pavan      23456
# 274   25  274   akhil  765432134
# 291   25  291    anil       3456
# 370   25  370    anil      34567
# 445   25  445   pavan      54321
# 482   25  482    anil      34567
# 514   25  514     jay      23456
# 541   25  541   akhil    8765432
# 553   25  553   ashok       3456
# 570   25  570   akhil      34567
# 579   25  579    anil      34567
# 626   25  626    anil     123456
# 632   25  632     jay     123456
# 669   25  669     jay    2345678
# 691   25  691  rajesh      54321
# 722   25  722   pavan      56789
# 731   25  731  rajesh      54321
# 791   25  791   akhil  765432134
# 802   25  802   pavan      34567
# 813   25  813     jay      34567
# 815   25  815  rajesh      54321
# 832   25  832   ashok      34567
# 834   25  834     jay      56789
# ...

# %%
df[df.name=="jay"]
# Out:
#      age   id name        sal
# 3     30    3  jay       3456
# 7     55    7  jay    2345678
# 11    51   11  jay      34567
# 14    37   14  jay       3456
# 17    56   17  jay      23456
# 21    43   21  jay  765432134
# 24    57   24  jay      34567
# 27    49   27  jay       3456
# 31    32   31  jay       3456
# 32    39   32  jay      23456
# 35    31   35  jay      34567
# 39    35   39  jay      34567
# 40    26   40  jay      56789
# 51    55   51  jay    2345678
# 54    47   54  jay      34567
# 61    37   61  jay      23456
# 75    31   75  jay     123456
# 88    52   88  jay      34567
# 101   30  101  jay      54321
# 104   41  104  jay     123456
# 119   59  119  jay  765432134
# 126   42  126  jay      23456
# 135   42  135  jay     123456
# 140   53  140  jay      54321
# 143   24  143  jay      34567
# 144   42  144  jay    8765432
# 162   41  162  jay    2345678
# 165   23  165  jay       3456
# 174   25  174  jay     123456
# 188   38  188  jay      23456
# ...

# %%
print df.sal
# Out:
# 0        8765432
# 1        8765432
# 2           3456
# 3           3456
# 4          54321
# 5           3456
# 6          54321
# 7        2345678
# 8          56789
# 9        2345678
# 10       2345678
# 11         34567
# 12          3456
# 13         56789
# 14          3456
# 15         54321
# 16          3456
# 17         23456
# 18          3456
# 19         23456
# 20     765432134
# 21     765432134
# 22     765432134
# 23         34567
# 24         34567
# 25         56789
# 26         34567
# 27          3456
# 28         23456
# 29       2345678
#          ...
# 970        56789
# 971        54321
# 972      2345678
# 973      8765432
# 974         3456
# 975       123456
# 976        54321
# 977        34567
# 978       123456
# 979       123456
# 980      8765432
# 981        34567
# 982        34567
# 983        54321
# 984      8765432
# 985      8765432
# 986    765432134
# 987      8765432
# 988      2345678
# 989        23456
# 990       123456
# ...

# %%
print df.age
# Out:
# 0      58
# 1      32
# 2      52
# 3      30
# 4      43
# 5      31
# 6      48
# 7      55
# 8      27
# 9      41
# 10     32
# 11     51
# 12     38
# 13     30
# 14     37
# 15     48
# 16     34
# 17     56
# 18     50
# 19     57
# 20     37
# 21     43
# 22     30
# 23     37
# 24     57
# 25     42
# 26     54
# 27     49
# 28     58
# 29     28
#        ..
# 970    59
# 971    41
# 972    30
# 973    44
# 974    50
# 975    39
# 976    27
# 977    50
# 978    56
# 979    47
# 980    41
# 981    33
# 982    52
# 983    53
# 984    30
# 985    54
# 986    52
# 987    46
# 988    41
# 989    54
# 990    32
# 991    36
# 992    47
# 993    42
# 994    43
# 995    58
# 996    46
# 997    46
# 998    25
# 999    55
# Name: age, Length: 1000, dtype: int64

# %%
df.age.max()
# Out:
# 59

# %%
df.sal.max()
# Out:
# 765432134

# %%
len(df)
# Out:
# 1000

# %%
df.sal.mean()
# Out:
# 66962954.477

# %%
df[df.sal.mean()<df.sal]
# Out:
#      age   id    name        sal
# 20    37   20    anil  765432134
# 21    43   21     jay  765432134
# 22    30   22  rajesh  765432134
# 33    50   33  rajesh  765432134
# 70    41   70   ashok  765432134
# 105   36  105   ashok  765432134
# 107   24  107    anil  765432134
# 109   35  109   akhil  765432134
# 110   38  110  rajesh  765432134
# 115   57  115  rajesh  765432134
# 119   59  119     jay  765432134
# 157   54  157   akhil  765432134
# 177   54  177   ashok  765432134
# 186   39  186  rajesh  765432134
# 190   47  190   pavan  765432134
# 210   55  210  rajesh  765432134
# 211   37  211   ashok  765432134
# 217   26  217  rajesh  765432134
# 241   30  241   ashok  765432134
# 256   44  256  rajesh  765432134
# 257   45  257   pavan  765432134
# 264   24  264    anil  765432134
# 274   25  274   akhil  765432134
# 276   30  276     jay  765432134
# 282   33  282  rajesh  765432134
# 296   27  296   pavan  765432134
# 299   28  299   pavan  765432134
# ...

# %%
df.groupby("age")

# %%
df.groupby("age").sum()
# Out:
#         id         sal
# age
# 23   14926  1588868941
# 24   14677  2341849222
# 25   19754  1551991901
# 26    8118  1542533636
# 27   11626   796771133
# 28    9548  3845785350
# 29   13808   803949896
# 30   14464  4624739952
# 31   12590  3080023827
# 32   10118    34102945
# 33   13165  3845341149
# 34   19015  1580408197
# 35   15489  2354557122
# 36   17030  3845893985
# 37    9516  1553796103
# 38    6840  2303674662
# 39   10362  2336708734
# 40   12331   779818039
# 41   12569   806279278
# 42   12249  2327884535
# 43   13765  1552080546
# 44   16059  3086999130
# 45   15368  1560462767
# 46   19289  1572015352
# 47   12183  1553799067
# 48   14084  1556166721
# 49   15362  1562780305
# 50   12904  1556029190
# 51    9349     7544674
# 52   11052  2316878611
# 53   13798    45547884
# 54   11697  2319361326
# 55   16929   819546433
# 56   14053    47723435
# 57   11053  2319671937
# 58   17803   826142729
# 59   16557  2315225763

# %%
import matplotlib.pyplot as plt
df.groupby("age").sum().plot()
plt.show()

# %%
sum_age=df.groupby("age").sum()

# %%
sum_age.sort_values(by="sal")
# Out:
#         id         sal
# age
# 51    9349     7544674
# 32   10118    34102945
# 53   13798    45547884
# 56   14053    47723435
# 40   12331   779818039
# 27   11626   796771133
# 29   13808   803949896
# 41   12569   806279278
# 55   16929   819546433
# 58   17803   826142729
# 26    8118  1542533636
# 25   19754  1551991901
# 43   13765  1552080546
# 37    9516  1553796103
# 47   12183  1553799067
# 50   12904  1556029190
# 48   14084  1556166721
# 45   15368  1560462767
# 49   15362  1562780305
# 46   19289  1572015352
# 34   19015  1580408197
# 23   14926  1588868941
# 38    6840  2303674662
# 59   16557  2315225763
# 52   11052  2316878611
# 54   11697  2319361326
# 57   11053  2319671937
# 42   12249  2327884535
# 39   10362  2336708734
# 24   14677  2341849222
# 35   15489  2354557122
# 31   12590  3080023827
# 44   16059  3086999130
# 33   13165  3845341149
# 28    9548  3845785350
# 36   17030  3845893985
# 30   14464  4624739952

# %%
sum_age.sort_values?

# %%
sum_age.sort_values(by="sal",ascending=False)
# Out:
#         id         sal
# age
# 30   14464  4624739952
# 36   17030  3845893985
# 28    9548  3845785350
# 33   13165  3845341149
# 44   16059  3086999130
# 31   12590  3080023827
# 35   15489  2354557122
# 24   14677  2341849222
# 39   10362  2336708734
# 42   12249  2327884535
# 57   11053  2319671937
# 54   11697  2319361326
# 52   11052  2316878611
# 59   16557  2315225763
# 38    6840  2303674662
# 23   14926  1588868941
# 34   19015  1580408197
# 46   19289  1572015352
# 49   15362  1562780305
# 45   15368  1560462767
# 48   14084  1556166721
# 50   12904  1556029190
# 47   12183  1553799067
# 37    9516  1553796103
# 43   13765  1552080546
# 25   19754  1551991901
# 26    8118  1542533636
# 58   17803   826142729
# 55   16929   819546433
# 41   12569   806279278
# 29   13808   803949896
# 27   11626   796771133
# 40   12331   779818039
# 56   14053    47723435
# 53   13798    45547884
# 32   10118    34102945
# 51    9349     7544674

# %%
sum_age.sort_values(by="sal",ascending=False).head(10)
# Out:
#         id         sal
# age
# 30   14464  4624739952
# 36   17030  3845893985
# 28    9548  3845785350
# 33   13165  3845341149
# 44   16059  3086999130
# 31   12590  3080023827
# 35   15489  2354557122
# 24   14677  2341849222
# 39   10362  2336708734
# 42   12249  2327884535

# %%
sum_age.sort_values(by="sal",ascending=False).head(10).plot(kind="bar")
plt.show()

# %%
sum_age.sort_values(by="sal",ascending=False).head(10).plot?
# Out:
# Object `plot` not found.

# %%
sum_age.sort_values(by="sal",ascending=False).head(10).plot

# %%
df.plot?

# %%
sum_age.sort_values(by="sal",ascending=False).head(10).plot(kind="bar",colormap="red")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-698e4a3048d0> in <module>()
# ----> 1 sum_age.sort_values(by="sal",ascending=False).head(10).plot(kind="bar",colormap="red")
#
# /home/khyaathi-python/anaconda2/lib/python2.7/site-packages/pandas/plotting/_core.pyc in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2625                           fontsize=fontsize, colormap=colormap, table=table,
#    2626                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2627                           sort_columns=sort_columns, **kwds)
#    2628     __call__.__doc__ = plot_frame.__doc__
#    2629
#
# ...

# %%
sum_age.sort_values(by="sal",ascending=False).head(10).plot(kind="bar",colormap="tab20")
plt.show()

# %%
sum_age.sort_values(by="sal",ascending=False).head(10).plot(kind="bar",colormap="tab20")
plt.savefig("agegraph.png")
plt.show()

# %%
df.to_csv("persosndata.csv")

# %%
df=pd.read_csv?

# %%
df=pd.read_csv("persosndata.csv")

# %%
df.tail(10)
# Out:
#      age   id    name      sal
# 990   32  990     jay   123456
# 991   36  991   ashok     3456
# 992   47  992   akhil     3456
# 993   42  993  rajesh    56789
# 994   43  994  rajesh  2345678
# 995   58  995   akhil    34567
# 996   46  996   pavan  2345678
# 997   46  997   ashok    23456
# 998   25  998   pavan    34567
# 999   55  999     jay    56789

# %%
import sqlite3
try:
    con=sqlite3.connect("db1.db")
    cur=con.cursor()
    cur.execute("create table person(id int, name varchar(250),age int,sal int)")
    for row in data:
        q="insert into person values(%(id)s, '%(name)s', %(age)s, %(sal)s)"%row
        cur.execute(q)
except Exception as err:
    print err
finally:
    con.commit()
    con.close()

# %%
con=sqlite3.connect("db1.db")
df = pd.read_sql("select * from person",con)

# %%
print df.head(10)
# Out:
#    id    name  age      sal
# 0   0  rajesh   58  8765432
# 1   1   ashok   32  8765432
# 2   2   pavan   52     3456
# 3   3     jay   30     3456
# 4   4   pavan   43    54321
# 5   5   ashok   31     3456
# 6   6  rajesh   48    54321
# 7   7     jay   55  2345678
# 8   8    anil   27    56789
# 9   9   pavan   41  2345678

# %%
df.sort_values(by="sal").tail(10)[["name","sal"]]
# Out:
#        name        sal
# 115  rajesh  765432134
# 741  rajesh  765432134
# 743    anil  765432134
# 746  rajesh  765432134
# 351     jay  765432134
# 119     jay  765432134
# 344   pavan  765432134
# 760     jay  765432134
# 768  rajesh  765432134
# 791   akhil  765432134

# %%
df.sort_values(by="sal").tail(10)[["name","sal"]].plot(kind="bar")
plt.show()

# %%
df.sort_values(by="sal").tail(10)[["name","sal"]].plot(kind="bar",x="name",y="sal")
plt.show()

# %%
df = pd.read_html("https://www.w3schools.com/html/html_tables.asp")

# %%
for table in df:
    print table
# Out:
#                               0                 1        2
# 0                       Company           Contact  Country
# 1           Alfreds Futterkiste      Maria Anders  Germany
# 2    Centro comercial Moctezuma   Francisco Chang   Mexico
# 3                  Ernst Handel     Roland Mendel  Austria
# 4                Island Trading     Helen Bennett       UK
# 5  Laughing Bacchus Winecellars   Yoshi Tannamuri   Canada
# 6  Magazzini Alimentari Riuniti  Giovanni Rovelli    Italy
#              0                                                  1
# 0          Tag                                        Description
# 1      <table>                                    Defines a table
# 2         <th>                   Defines a header cell in a table
# 3         <tr>                           Defines a row in a table
# 4         <td>                          Defines a cell in a table
# 5    <caption>                            Defines a table caption
# ...

# %%
con=sqlite3.connect("db1.db")
df = pd.read_sql("select * from person",con)
req_data=df.sort_values(by="sal").tail(10)[["name","sal"]]

# %%
req_data.to_json()
# Out:
# '{"name":{"115":"rajesh","741":"rajesh","743":"anil","746":"rajesh","351":"jay","119":"jay","344":"pavan","760":"jay","768":"rajesh","791":"akhil"},"sal":{"115":765432134,"741":765432134,"743":765432134,"746":765432134,"351":765432134,"119":765432134,"344":765432134,"760":765432134,"768":765432134,"791":765432134}}'
