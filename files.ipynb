# %%
f=open("data.csv","w")

# %%
f.write("some data")

# %%
# refresh the buffer using two ways: f.close, f.flush
# of you close a file you could not do any operation. If you flush a file you can do some operaions furthur

# %%
f.close()

# %%
f.write("some more data after close")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-d668ee170544> in <module>()
# ----> 1 f.write("some more data after close")
#
# ValueError: I/O operation on closed file

# %%
f=open("data.csv","w")

# %%
f=open("data.csv","w")
f.write("some data")
f.flush()

# %%
f.write("data after flush")

# %%
f.close()

# %%
f=open("data.csv","w")
f.write("some data")
f.flush()
f.write("data after flush")
f.close()

# %%
f=open("data.csv","a")
f.write("\n content added at append mode")

# %%
f.close()

# %%
f=open("data1.csv","a")
f.write("some data")
f.close()

# %%
import random
names=["anil","jayaram","Dhanush","ramesh","Ravi"]
ages=[23,45,34,56,60]
sals=[23000,34000,45000,60000]
for i in range(100):
    row= "%s,%s,%s"%(random.choice(names),random.choice(ages),random.choice(sals))
    print row
# Out:
# jayaram,34,60000
# anil,45,23000
# jayaram,56,23000
# Ravi,60,34000
# Dhanush,34,23000
# anil,56,45000
# anil,34,23000
# Dhanush,60,45000
# anil,34,23000
# ramesh,60,34000
# Ravi,34,34000
# Ravi,60,23000
# Dhanush,45,60000
# ramesh,56,34000
# Dhanush,45,60000
# Dhanush,45,60000
# ramesh,34,23000
# jayaram,56,45000
# Ravi,23,45000
# anil,23,23000
# anil,23,60000
# Dhanush,45,45000
# anil,34,23000
# ramesh,34,34000
# ramesh,45,45000
# ramesh,60,34000
# Dhanush,34,23000
# Dhanush,60,23000
# jayaram,34,23000
# Dhanush,60,23000
# anil,56,60000
# Ravi,23,34000
# Dhanush,34,60000
# Ravi,45,34000
# jayaram,23,34000
# Ravi,45,60000
# Dhanush,60,34000
# anil,60,45000
# Ravi,60,23000
# Ravi,34,23000
# anil,60,34000
# Dhanush,56,60000
# anil,45,23000
# Dhanush,34,60000
# anil,23,60000
# jayaram,56,23000
# Dhanush,56,23000
# Dhanush,60,23000
# Ravi,60,34000
# Ravi,34,45000
# Ravi,34,45000
# ramesh,45,45000
# Ravi,23,45000
# Ravi,60,34000
# Dhanush,34,60000
# jayaram,34,45000
# Ravi,60,34000
# ...

# %%
import random
f=open("data.csv","w")
names=["anil","jayaram","Dhanush","ramesh","Ravi"]
ages=[23,45,34,56,60]
sals=[23000,34000,45000,60000]
for i in range(100):
    row= "%s,%s,%s\n"%(random.choice(names),random.choice(ages),random.choice(sals))
    f.write(row)
f.close()

# %%
f=open("data1.csv","w")
l=["name1","name2","name3"]
f.writelines(l)
f.close()

# %%
import random
f=open("data.csv","w")
names=["anil","jayaram","Dhanush","ramesh","Ravi"]
ages=[23,45,34,56,60]
sals=[23000,34000,45000,60000]
data = map(lambda x:"%s,%s,%s\n"%(random.choice(names),random.choice(ages),random.choice(sals)),range(100))
print data
f.writelines(data)
f.close()
# Out:
# ['Ravi,56,34000\n', 'Ravi,23,34000\n', 'ramesh,56,45000\n', 'ramesh,23,23000\n', 'anil,34,45000\n', 'ramesh,34,23000\n', 'Dhanush,23,45000\n', 'Dhanush,34,23000\n', 'ramesh,56,34000\n', 'jayaram,23,23000\n', 'Dhanush,23,23000\n', 'jayaram,56,60000\n', 'jayaram,60,34000\n', 'jayaram,23,34000\n', 'anil,45,23000\n', 'Ravi,23,34000\n', 'Dhanush,60,34000\n', 'ramesh,60,34000\n', 'Ravi,56,60000\n', 'Ravi,56,34000\n', 'Dhanush,34,34000\n', 'anil,34,23000\n', 'ramesh,34,45000\n', 'anil,45,34000\n', 'jayaram,60,34000\n', 'jayaram,60,60000\n', 'anil,45,23000\n', 'Dhanush,45,45000\n', 'anil,23,45000\n', 'jayaram,56,45000\n', 'Ravi,60,45000\n', 'ramesh,60,60000\n', 'anil,45,23000\n', 'jayaram,34,60000\n', 'jayaram,56,34000\n', 'Dhanush,23,23000\n', 'anil,45,45000\n', 'Dhanush,23,34000\n', 'Ravi,23,23000\n', 'ramesh,60,34000\n', 'jayaram,56,45000\n', 'Ravi,34,34000\n', 'anil,45,45000\n', 'Ravi,56,60000\n', 'jayaram,34,23000\n', 'ramesh,56,60000\n', 'Ravi,34,34000\n', 'Dhanush,34,23000\n', 'anil,5
# ...

# %%
f=open("data2.csv","r")
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-20-ed19d2a6c5c9> in <module>()
# ----> 1 f=open("data2.csv","r")
#
# IOError: [Errno 2] No such file or directory: 'data2.csv'

# %%
import os

# %%
os.path.isfile("data2.csv")
# Out:
# False

# %%
os.path.isfile("data.csv")
# Out:
# True

# %%
file_path=raw_input("Enter a file path to read:")
if os.path.isfile(file_path):
    f=open(file_path,"r")
    data = f.read()
    print data
else:
    print "give file not found"
# Out:
# Enter a file path to read:data2.csv
# give file not found

# %%
file_path=raw_input("Enter a file path to read:")
if os.path.isfile(file_path):
    f=open(file_path,"r")
    data = f.read()
    print data
else:
    print "give file not found"
# Out:
# Enter a file path to read:data.csv
# Ravi,56,34000
# Ravi,23,34000
# ramesh,56,45000
# ramesh,23,23000
# anil,34,45000
# ramesh,34,23000
# Dhanush,23,45000
# Dhanush,34,23000
# ramesh,56,34000
# jayaram,23,23000
# Dhanush,23,23000
# jayaram,56,60000
# jayaram,60,34000
# jayaram,23,34000
# anil,45,23000
# Ravi,23,34000
# Dhanush,60,34000
# ramesh,60,34000
# Ravi,56,60000
# Ravi,56,34000
# Dhanush,34,34000
# anil,34,23000
# ramesh,34,45000
# anil,45,34000
# jayaram,60,34000
# jayaram,60,60000
# anil,45,23000
# Dhanush,45,45000
# anil,23,45000
# jayaram,56,45000
# Ravi,60,45000
# ramesh,60,60000
# anil,45,23000
# jayaram,34,60000
# jayaram,56,34000
# Dhanush,23,23000
# anil,45,45000
# Dhanush,23,34000
# Ravi,23,23000
# ramesh,60,34000
# jayaram,56,45000
# Ravi,34,34000
# anil,45,45000
# Ravi,56,60000
# jayaram,34,23000
# ramesh,56,60000
# Ravi,34,34000
# Dhanush,34,23000
# anil,56,45000
# anil,23,23000
# jayaram,60,23000
# jayaram,23,60000
# jayaram,56,23000
# anil,56,23000
# ...

# %%
f=open("data.csv","r")
data = f.read()
print data
# Out:
# Ravi,56,34000
# Ravi,23,34000
# ramesh,56,45000
# ramesh,23,23000
# anil,34,45000
# ramesh,34,23000
# Dhanush,23,45000
# Dhanush,34,23000
# ramesh,56,34000
# jayaram,23,23000
# Dhanush,23,23000
# jayaram,56,60000
# jayaram,60,34000
# jayaram,23,34000
# anil,45,23000
# Ravi,23,34000
# Dhanush,60,34000
# ramesh,60,34000
# Ravi,56,60000
# Ravi,56,34000
# Dhanush,34,34000
# anil,34,23000
# ramesh,34,45000
# anil,45,34000
# jayaram,60,34000
# jayaram,60,60000
# anil,45,23000
# Dhanush,45,45000
# anil,23,45000
# jayaram,56,45000
# Ravi,60,45000
# ramesh,60,60000
# anil,45,23000
# jayaram,34,60000
# jayaram,56,34000
# Dhanush,23,23000
# anil,45,45000
# Dhanush,23,34000
# Ravi,23,23000
# ramesh,60,34000
# jayaram,56,45000
# Ravi,34,34000
# anil,45,45000
# Ravi,56,60000
# jayaram,34,23000
# ramesh,56,60000
# Ravi,34,34000
# Dhanush,34,23000
# anil,56,45000
# anil,23,23000
# jayaram,60,23000
# jayaram,23,60000
# jayaram,56,23000
# anil,56,23000
# Ravi,45,34000
# Dhanush,60,23000
# ...

# %%
f=open("data.csv","r")
data = f.read(500)
print data
print "second reading"
print "*"*100
data = f.read(500)
print data
# Out:
# Ravi,56,34000
# Ravi,23,34000
# ramesh,56,45000
# ramesh,23,23000
# anil,34,45000
# ramesh,34,23000
# Dhanush,23,45000
# Dhanush,34,23000
# ramesh,56,34000
# jayaram,23,23000
# Dhanush,23,23000
# jayaram,56,60000
# jayaram,60,34000
# jayaram,23,34000
# anil,45,23000
# Ravi,23,34000
# Dhanush,60,34000
# ramesh,60,34000
# Ravi,56,60000
# Ravi,56,34000
# Dhanush,34,34000
# anil,34,23000
# ramesh,34,45000
# anil,45,34000
# jayaram,60,34000
# jayaram,60,60000
# anil,45,23000
# Dhanush,45,45000
# anil,23,45000
# jayaram,56,45000
# Ravi,60,45000
# ramesh,60,60000
# second reading
# ****************************************************************************************************
#
# anil,45,23000
# jayaram,34,60000
# jayaram,56,34000
# Dhanush,23,23000
# anil,45,45000
# Dhanush,23,34000
# Ravi,23,23000
# ramesh,60,34000
# jayaram,56,45000
# Ravi,34,34000
# anil,45,45000
# Ravi,56,60000
# jayaram,34,23000
# ramesh,56,60000
# Ravi,34,34000
# Dhanush,34,23000
# anil,56,45000
# anil,23,23000
# ...

# %%
f=open("data.csv","r")
data = f.read(500)
print data
print "second reading"
print "*"*100
data = f.read(500)
print data
print "thired read:"
data = f.read()
print data
# Out:
# Ravi,56,34000
# Ravi,23,34000
# ramesh,56,45000
# ramesh,23,23000
# anil,34,45000
# ramesh,34,23000
# Dhanush,23,45000
# Dhanush,34,23000
# ramesh,56,34000
# jayaram,23,23000
# Dhanush,23,23000
# jayaram,56,60000
# jayaram,60,34000
# jayaram,23,34000
# anil,45,23000
# Ravi,23,34000
# Dhanush,60,34000
# ramesh,60,34000
# Ravi,56,60000
# Ravi,56,34000
# Dhanush,34,34000
# anil,34,23000
# ramesh,34,45000
# anil,45,34000
# jayaram,60,34000
# jayaram,60,60000
# anil,45,23000
# Dhanush,45,45000
# anil,23,45000
# jayaram,56,45000
# Ravi,60,45000
# ramesh,60,60000
# second reading
# ****************************************************************************************************
#
# anil,45,23000
# jayaram,34,60000
# jayaram,56,34000
# Dhanush,23,23000
# anil,45,45000
# Dhanush,23,34000
# Ravi,23,23000
# ramesh,60,34000
# jayaram,56,45000
# Ravi,34,34000
# anil,45,45000
# Ravi,56,60000
# jayaram,34,23000
# ramesh,56,60000
# Ravi,34,34000
# Dhanush,34,23000
# anil,56,45000
# anil,23,23000
# ...

# %%
f=open("data.csv","r")
print f.tell()
data = f.read(500)
#print data
print f.tell()
print "second reading"
print "*"*100
data = f.read(500)
#print data
print f.tell()
print "thired read:"
data = f.read()
#print data
print f.tell()
# Out:
# 0
# 500
# second reading
# ****************************************************************************************************
# 1000
# thired read:
# 1561

# %%
f=open("data.csv","r")
print f.tell()
data = f.read()
print data
print f.tell()
print "second reading"
print "*"*100
data = f.read()
#print data
print f.tell()
print "second tiem data:",data
# Out:
# 0
# Ravi,56,34000
# Ravi,23,34000
# ramesh,56,45000
# ramesh,23,23000
# anil,34,45000
# ramesh,34,23000
# Dhanush,23,45000
# Dhanush,34,23000
# ramesh,56,34000
# jayaram,23,23000
# Dhanush,23,23000
# jayaram,56,60000
# jayaram,60,34000
# jayaram,23,34000
# anil,45,23000
# Ravi,23,34000
# Dhanush,60,34000
# ramesh,60,34000
# Ravi,56,60000
# Ravi,56,34000
# Dhanush,34,34000
# anil,34,23000
# ramesh,34,45000
# anil,45,34000
# jayaram,60,34000
# jayaram,60,60000
# anil,45,23000
# Dhanush,45,45000
# anil,23,45000
# jayaram,56,45000
# Ravi,60,45000
# ramesh,60,60000
# anil,45,23000
# jayaram,34,60000
# jayaram,56,34000
# Dhanush,23,23000
# anil,45,45000
# Dhanush,23,34000
# Ravi,23,23000
# ramesh,60,34000
# jayaram,56,45000
# Ravi,34,34000
# anil,45,45000
# Ravi,56,60000
# jayaram,34,23000
# ramesh,56,60000
# Ravi,34,34000
# Dhanush,34,23000
# anil,56,45000
# anil,23,23000
# jayaram,60,23000
# jayaram,23,60000
# jayaram,56,23000
# anil,56,23000
# Ravi,45,34000
# Dhanush,60,23000
# ...

# %%
f=open("data.csv","r")
print f.tell()
data = f.read()
print data
f.seek(50)
data1=f.read()
print "data1=",data1
# Out:
# 0
# Ravi,56,34000
# Ravi,23,34000
# ramesh,56,45000
# ramesh,23,23000
# anil,34,45000
# ramesh,34,23000
# Dhanush,23,45000
# Dhanush,34,23000
# ramesh,56,34000
# jayaram,23,23000
# Dhanush,23,23000
# jayaram,56,60000
# jayaram,60,34000
# jayaram,23,34000
# anil,45,23000
# Ravi,23,34000
# Dhanush,60,34000
# ramesh,60,34000
# Ravi,56,60000
# Ravi,56,34000
# Dhanush,34,34000
# anil,34,23000
# ramesh,34,45000
# anil,45,34000
# jayaram,60,34000
# jayaram,60,60000
# anil,45,23000
# Dhanush,45,45000
# anil,23,45000
# jayaram,56,45000
# Ravi,60,45000
# ramesh,60,60000
# anil,45,23000
# jayaram,34,60000
# jayaram,56,34000
# Dhanush,23,23000
# anil,45,45000
# Dhanush,23,34000
# Ravi,23,23000
# ramesh,60,34000
# jayaram,56,45000
# Ravi,34,34000
# anil,45,45000
# Ravi,56,60000
# jayaram,34,23000
# ramesh,56,60000
# Ravi,34,34000
# Dhanush,34,23000
# anil,56,45000
# anil,23,23000
# jayaram,60,23000
# jayaram,23,60000
# jayaram,56,23000
# anil,56,23000
# Ravi,45,34000
# Dhanush,60,23000
# ...

# %%
f=open("data.csv","r")
print f.tell()
data = f.read()
print f.tell()
#print data
f.seek(50)
print f.tell()
data1=f.read()
#print "data1=",data1
# Out:
# 0
# 1561
# 50

# %%
f=open("data.csv","r")
print f.readline()
print f.readline()
print f.readline()
# Out:
# Ravi,56,34000
#
# Ravi,23,34000
#
# ramesh,56,45000

# %%
f.readlines()
# Out:
# ['ramesh,23,23000\n',
#  'anil,34,45000\n',
#  'ramesh,34,23000\n',
#  'Dhanush,23,45000\n',
#  'Dhanush,34,23000\n',
#  'ramesh,56,34000\n',
#  'jayaram,23,23000\n',
#  'Dhanush,23,23000\n',
#  'jayaram,56,60000\n',
#  'jayaram,60,34000\n',
#  'jayaram,23,34000\n',
#  'anil,45,23000\n',
#  'Ravi,23,34000\n',
#  'Dhanush,60,34000\n',
#  'ramesh,60,34000\n',
#  'Ravi,56,60000\n',
#  'Ravi,56,34000\n',
#  'Dhanush,34,34000\n',
#  'anil,34,23000\n',
#  'ramesh,34,45000\n',
#  'anil,45,34000\n',
#  'jayaram,60,34000\n',
#  'jayaram,60,60000\n',
#  'anil,45,23000\n',
#  'Dhanush,45,45000\n',
#  'anil,23,45000\n',
#  'jayaram,56,45000\n',
#  'Ravi,60,45000\n',
#  'ramesh,60,60000\n',
#  'anil,45,23000\n',
#  'jayaram,34,60000\n',
#  'jayaram,56,34000\n',
#  'Dhanush,23,23000\n',
#  'anil,45,45000\n',
#  'Dhanush,23,34000\n',
#  'Ravi,23,23000\n',
#  'ramesh,60,34000\n',
#  'jayaram,56,45000\n',
#  'Ravi,34,34000\n',
#  'anil,45,45000\n',
#  'Ravi,56,60000\n',
#  'jayaram,34,23000\n',
# ...

# %%
f=open("data.csv","r")
for row in f:
    print row
# Out:
# Ravi,56,34000
#
# Ravi,23,34000
#
# ramesh,56,45000
#
# ramesh,23,23000
#
# anil,34,45000
#
# ramesh,34,23000
#
# Dhanush,23,45000
#
# Dhanush,34,23000
#
# ramesh,56,34000
#
# jayaram,23,23000
#
# Dhanush,23,23000
#
# jayaram,56,60000
#
# jayaram,60,34000
#
# jayaram,23,34000
#
# anil,45,23000
#
# Ravi,23,34000
#
# Dhanush,60,34000
#
# ramesh,60,34000
#
# Ravi,56,60000
#
# Ravi,56,34000
#
# Dhanush,34,34000
#
# anil,34,23000
#
# ramesh,34,45000
#
# anil,45,34000
#
# jayaram,60,34000
#
# jayaram,60,60000
#
# anil,45,23000
#
# Dhanush,45,45000
#
# anil,23,45000
#
# jayaram,56,45000
#
# Ravi,60,45000
#
# ramesh,60,60000
#
# anil,45,23000
#
# jayaram,34,60000
#
# jayaram,56,34000
#
# Dhanush,23,23000
#
# anil,45,45000
#
# Dhanush,23,34000
#
# Ravi,23,23000
#
# ramesh,60,34000
#
# jayaram,56,45000
#
# Ravi,34,34000
#
# anil,45,45000
#
# Ravi,56,60000
#
# jayaram,34,23000
#
# ramesh,56,60000
#
# Ravi,34,34000
#
# Dhanush,34,23000
#
# anil,56,45000
#
# anil,23,23000
#
# jayaram,60,23000
#
# ...

# %%
f=open("data.csv","r")
for row in f:
    if "anil" in row:
        print row
# Out:
# anil,34,45000
#
# anil,45,23000
#
# anil,34,23000
#
# anil,45,34000
#
# anil,45,23000
#
# anil,23,45000
#
# anil,45,23000
#
# anil,45,45000
#
# anil,45,45000
#
# anil,56,45000
#
# anil,23,23000
#
# anil,56,23000
#
# anil,56,60000
#
# anil,23,34000
#
# anil,34,45000
#
# anil,45,45000
#
# anil,34,34000
#
# anil,34,34000
#
# anil,45,23000
#
# anil,56,60000

# %%
f=open("data.csv","r")
for row in f:
    if "anil" in row:
        print row.split(",")
# Out:
# ['anil', '34', '45000\n']
# ['anil', '45', '23000\n']
# ['anil', '34', '23000\n']
# ['anil', '45', '34000\n']
# ['anil', '45', '23000\n']
# ['anil', '23', '45000\n']
# ['anil', '45', '23000\n']
# ['anil', '45', '45000\n']
# ['anil', '45', '45000\n']
# ['anil', '56', '45000\n']
# ['anil', '23', '23000\n']
# ['anil', '56', '23000\n']
# ['anil', '56', '60000\n']
# ['anil', '23', '34000\n']
# ['anil', '34', '45000\n']
# ['anil', '45', '45000\n']
# ['anil', '34', '34000\n']
# ['anil', '34', '34000\n']
# ['anil', '45', '23000\n']
# ['anil', '56', '60000\n']

# %%
f=open("data.csv","r")
for row in f:
    if "anil" in row:
        print row.split(",")[-1]
# Out:
# 45000
#
# 23000
#
# 23000
#
# 34000
#
# 23000
#
# 45000
#
# 23000
#
# 45000
#
# 45000
#
# 45000
#
# 23000
#
# 23000
#
# 60000
#
# 34000
#
# 45000
#
# 45000
#
# 34000
#
# 34000
#
# 23000
#
# 60000

# %%
f=open("data.csv","r")
for row in f:
    if "anil" in row:
        print row.split(",")[-1].strip()
# Out:
# 45000
# 23000
# 23000
# 34000
# 23000
# 45000
# 23000
# 45000
# 45000
# 45000
# 23000
# 23000
# 60000
# 34000
# 45000
# 45000
# 34000
# 34000
# 23000
# 60000

# %%
f=open("data.csv","r")
for row in f:
    if "anil" in row:
        print type(row.split(",")[-1].strip())
# Out:
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>
# <type 'str'>

# %%
f=open("data.csv","r")
for row in f:
    if "anil" in row:
        print int(row.split(",")[-1].strip())
# Out:
# 45000
# 23000
# 23000
# 34000
# 23000
# 45000
# 23000
# 45000
# 45000
# 45000
# 23000
# 23000
# 60000
# 34000
# 45000
# 45000
# 34000
# 34000
# 23000
# 60000

# %%
f=open("data.csv","r")
sum1=0
for row in f:
    if "anil" in row:
        sum1 = sum1+int(row.split(",")[-1].strip())
print sum1
# Out:
# 732000

# %%
f=open("data.csv","r")
data_anil_sals=map(lambda row:int(row.split(",")[-1].strip()) if "anil" in row else 0,f)
print sum(data_anil_sals)
# Out:
# 732000

# %%
f=open("data1.csv","w")
f.write(1234567)
f.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-1cd82d309b0c> in <module>()
#       1 f=open("data1.csv","w")
# ----> 2 f.write(1234567)
#       3 f.close()
#
# TypeError: expected a string or other character buffer object

# %%
f=open("data1.csv","w")
f.write(str(1234567))
f.close()

# %%
f=open("data1.csv","r")
data = f.read()
print data
print type(data)
# Out:
# 1234567
# <type 'str'>

# %%
f=open("data1.csv","r")
data = f.read()
print data
print type(data)
print int(data)
# Out:
# 1234567
# <type 'str'>
# 1234567

# %%
#data=[{"name":"name1"},{"name":"name2"}]
# read .json file
# read .yaml file
